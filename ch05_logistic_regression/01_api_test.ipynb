# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(
    solver='sag',
    multi_class='multinomal',
    max_iter=1000,
    class_weight='balanced',
    random_state=42,
    penalty='l1',
    C=1.0
)
